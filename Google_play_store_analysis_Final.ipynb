# %% [markdown]
# <a href="https://colab.research.google.com/github/IrfanPavel/Google_Play_Store/blob/main/Google_play_store_analysis_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing the dependecies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Downloading the dataset
#  ↪ using opendatsets

# %% [markdown]
# # Data Preparation and Cleaing
#  ↪ Load the csv file with the pandas
#
#  ↪ creating the dataframe and understanding the data present in the dataset
#
#  ↪ Dealing with the missing data and the incorrect records

# %%
df = pd.read_csv('/content/Google-Playstore.csv')
# Out:
# <ipython-input-355-bc0fb153391e>:1: DtypeWarning: Columns (8,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Google-Playstore.csv')

# %% [markdown]
#  viewing the first 5 rows of the datset

# %%
df.head(5)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 0              10.0              15.0  True    0.0      USD   10M
# 1            5000.0            7662.0  True    0.0      USD  2.9M
# 2              50.0              58.0  True    0.0      USD  3.7M
# 3              10.0              19.0  True    0.0      USD  1.8M
# 4             100.0             478.0  True    0.0      USD  6.2M
#
#   Minimum Android                       Developer Id  \
# 0      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1      5.0 and up                         Webserveis
# 2    4.0.3 and up                         Cabin Crew
# 3    4.0.3 and up                Climate Smart Tech2
# 4      4.1 and up              Rafal Milek-Horodyski
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35

# %% [markdown]
# Let's see what are the columns were given in the Google-Playstore dataset

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %% [markdown]
# let's see the shape of the dataset

# %%
df.shape
# Out:
# (179163, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179163 entries, 0 to 179162
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   App Name           179162 non-null  object
#  1   App Id             179163 non-null  object
#  2   Category           179162 non-null  object
#  3   Rating             177414 non-null  float64
#  4   Rating Count       177414 non-null  float64
#  5   Installs           179149 non-null  object
#  6   Minimum Installs   179149 non-null  float64
#  7   Maximum Installs   179162 non-null  float64
#  8   Free               179162 non-null  object
#  9   Price              179162 non-null  float64
#  10  Currency           179144 non-null  object
#  11  Size               179150 non-null  object
#  12  Minimum Android    178645 non-null  object
#  13  Developer Id       179161 non-null  object
#  14  Developer Website  120503 non-null  object
#  15  Developer Email    179161 non-null  object
#  16  Released           173750 non-null  object
#  17  Last Updated       179162 non-null  object
#  18  Content Rating     179162 non-null  object
#  19  Privacy Policy     146802 non-null  object
#  20  Ad Supported       179162 non-null  object
#  21  In App Purchases   179162 non-null  object
#  22  Editors Choice     179162 non-null  object
#  23  Scraped Time       179162 non-null  object
# dtypes: float64(5), object(19)
# memory usage: 32.8+ MB

# %% [markdown]
# ## Observation:
#
# ---
# 1. The dataset having   2312944 rows and 24 columns
# 2. The columns in the dataset are:
#
#         'App Name', 'App Id', 'Category', 'Rating', 'Rating Count, Installs','Minimum Installs', 'Maximum Installs', 'Free', 'Price',
#         'Currency','Size', 'Minimum Android', 'Developer Id', 'Developer Website','Developer Email', 'Released', 'Last Updated',
#         'Content Rating','Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice','Scraped Time'

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()
# Out:
#               Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  177414.000000  1.774140e+05      1.791490e+05      1.791620e+05
# mean        2.201314  2.669267e+03      1.817949e+05      2.958397e+05
# std         2.106739  1.426057e+05      1.339521e+07      1.756242e+07
# min         0.000000  0.000000e+00      0.000000e+00      0.000000e+00
# 25%         0.000000  0.000000e+00      5.000000e+01      8.300000e+01
# 50%         2.900000  6.000000e+00      5.000000e+02      6.980000e+02
# 75%         4.300000  4.300000e+01      5.000000e+03      7.433750e+03
# max         5.000000  3.747901e+07      5.000000e+09      6.156519e+09
#
#                Price
# count  179162.000000
# mean        0.091439
# std         1.766336
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       399.990000

# %% [markdown]
# ## Observation :
#
# ---
# 1. we have 5 numerical columns in our dataset

# %% [markdown]
# To look the entire columns we can use pandas functon pd.set_option()

# %%
 pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 0              10.0              15.0  True    0.0      USD   10M
# 1            5000.0            7662.0  True    0.0      USD  2.9M
# 2              50.0              58.0  True    0.0      USD  3.7M
# 3              10.0              19.0  True    0.0      USD  1.8M
# 4             100.0             478.0  True    0.0      USD  6.2M
#
#   Minimum Android                       Developer Id  \
# 0      7.1 and up  Jean Confident Irénée NIYIZIBYOSE
# 1      5.0 and up                         Webserveis
# 2    4.0.3 and up                         Cabin Crew
# 3    4.0.3 and up                Climate Smart Tech2
# 4      4.1 and up              Rafal Milek-Horodyski
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35

# %% [markdown]
# ## Missing values in the data

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Developer Website    58660
# Privacy Policy       32361
# Released              5413
# Rating                1749
# Rating Count          1749
# Minimum Android        518
# Currency                19
# Minimum Installs        14
# Installs                14
# Size                    13
# Developer Id             2
# Developer Email          2
# In App Purchases         1
# Last Updated             1
# Content Rating           1
# Editors Choice           1
# Ad Supported             1
# App Name                 1
# Price                    1
# Free                     1
# Maximum Installs         1
# Category                 1
# Scraped Time             1
# App Id                   0
# dtype: int64

# %% [markdown]
# # **Exploratory Analysis and Visualization**

# %% [markdown]
# ## Let's plot the missing null values

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,6)
sns.heatmap(df.isnull(),yticklabels = False, cbar = False , cmap = 'viridis')
plt.title("Missing null values")
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %% [markdown]
# Let's see the missing percentage in data

# %%
missing_percentage = df.isnull().sum().sort_values(ascending = False)/len(df)
missing_percentage
# Out:
# Developer Website    0.327411
# Privacy Policy       0.180623
# Released             0.030213
# Rating               0.009762
# Rating Count         0.009762
# Minimum Android      0.002891
# Currency             0.000106
# Minimum Installs     0.000078
# Installs             0.000078
# Size                 0.000073
# Developer Id         0.000011
# Developer Email      0.000011
# In App Purchases     0.000006
# Last Updated         0.000006
# Content Rating       0.000006
# Editors Choice       0.000006
# Ad Supported         0.000006
# App Name             0.000006
# Price                0.000006
# Free                 0.000006
# Maximum Installs     0.000006
# Category             0.000006
# Scraped Time         0.000006
# App Id               0.000000
# dtype: float64

# %% [markdown]
# ## Let's plot the missing percentage of null values

# %%
missing_percentage = missing_percentage[missing_percentage != 0] # Only the missing data
import matplotlib
matplotlib.rcParams['figure.figsize'] = (20,6)
missing_percentage.plot(kind = 'barh')
plt.title("Missig percentage of null values")
# Out:
# Text(0.5, 1.0, 'Missig percentage of null values')

# %% [markdown]
# ## Observation :
#
#
# Dealing with the null values
#
#
# 1. The columns having highest percentage of null values are :
# * Developer Website
# * Privacy Policy
#
# these two are not that much helpful if we want we can drop these columns and in the further steps we drop and add some features in the dataset after the Analysis.
#
# 2. we can drop the small null values for the columns
#
# * App name
# * Size
# * Currency
# * Installs
# * Minimum Installs
# * Developer Id
# * Developer Email
#
# 3. Rating,Rating Count,Released are important column so it is good to fill the null values.
#
# * Rating
# * Rating count
# * Minimum Andriod
# * Released

# %% [markdown]
# ## from observation 2 droping the null values of the columns got selected

# %%
df.dropna(subset = ['App Name','Size','Currency','Installs','Minimum Installs','Developer Id','Developer Email'], inplace = True)

# %%
df.isnull().sum()
# Out:
# App Name                 0
# App Id                   0
# Category                 0
# Rating                1722
# Rating Count          1722
# Installs                 0
# Minimum Installs         0
# Maximum Installs         0
# Free                     0
# Price                    0
# Currency                 0
# Size                     0
# Minimum Android        517
# Developer Id             0
# Developer Website    58652
# Developer Email          0
# Released              5387
# Last Updated             0
# Content Rating           0
# Privacy Policy       32355
# Ad Supported             0
# In App Purchases         0
# Editors Choice           0
# Scraped Time             0
# dtype: int64

# %% [markdown]
# ## Now let's start cleaning the each row

# %% [markdown]
# checking any duplicates in the App Name

# %%
boolean = df['App Name'].duplicated().any()
boolean
# Out:
# True

# %%
df['App Name'].value_counts()
# Out:
# Tic Tac Toe                      32
# Flashlight                       25
# Calculator                       21
# BMI Calculator                   17
# Age Calculator                   15
#                                  ..
# leqqr - Eten bestellen            1
# JUADSA                            1
# Bona Robot                        1
# New Hindi Shayari 2021            1
# American Society of Employers     1
# Name: App Name, Length: 176909, dtype: int64

# %% [markdown]
# from the above cell output we can see that App Name column has multiple rows. Let's check out that data in those rows is identical or not

# %%
df[df['App Name'] == 'Tic Tac Toe']
# Out:
#            App Name                                   App Id Category  Rating  \
# 3918    Tic Tac Toe                 com.dev.atte.tic_tac_toe   Puzzle     0.0
# 13758   Tic Tac Toe                         com.md.tictactoe    Board     0.0
# 25351   Tic Tac Toe              com.sthirumuru.tictactoenew    Board     4.2
# 28142   Tic Tac Toe                     com.fsk00x.TicTacToe    Board     0.0
# 30962   Tic Tac Toe               net.snatchdreams.tictactoe   Puzzle     0.0
# 42602   Tic Tac Toe                      visu.suni.tictactoe   Casual     3.7
# 48854   Tic Tac Toe                  com.tictactoe.nesimapps   Puzzle     0.0
# 52301   Tic Tac Toe                   br.com.hawks.tictactoe   Casual     5.0
# 58474   Tic Tac Toe                    com.ujwal.tic_tac_toe    Board     0.0
# 71416   Tic Tac Toe                    com.eastesh.tictactoe   Puzzle     0.0
# 83551   Tic Tac Toe                     com.popoko.tictactoe    Board     3.9
# 92824   Tic Tac Toe             com.BarricaGames.tic_tac_toe   Casual     NaN
# 93663   Tic Tac Toe       pritesh.patel.cyberpaths.multigame   Arcade     4.8
# 94848   Tic Tac Toe                       com.eros.tictactoe   Casual     5.0
# 94997   Tic Tac Toe                  com.techpalle.tictactoe   Puzzle     0.0
# 105963  Tic Tac Toe                 easytuto.com.mytictactoe    Board     0.0
# 109212  Tic Tac Toe                     com.agroup.tictactoe   Puzzle     0.0
# 113737  Tic Tac Toe   com.gmail.luvyashila.c48tictactoemadhu    Board     0.0
# 117146  Tic Tac Toe                 com.LordBailey.TicTacToe   Arcade     0.0
# 121083  Tic Tac Toe                     com.tictactoe.wlid24   Casual     0.0
# 121529  Tic Tac Toe                   com.a.honey1.tictactoe    Board     0.0
# 125780  Tic Tac Toe                singh.harsh.org.tictactoe   Puzzle     4.9
# 129993  Tic Tac Toe             com.bigbrainkraken.tictactoe    Board     3.9
# 139673  Tic Tac Toe                 com.progressio.tictactoe    Board     4.6
# 150628  Tic Tac Toe                com.ProlificDev.tictactoe    Board     4.8
# 153658  Tic Tac Toe              com.uldixapps.tictactoefree   Puzzle     0.0
# 157170  Tic Tac Toe                 code.kaalgroup.tictactoe    Board     0.0
# 157357  Tic Tac Toe                  com.soumyadip.tictactoe   Casual     4.9
# 157422  Tic Tac Toe      com.smartjaguardevelopers.tictactoe    Board     0.0
# 161618  Tic Tac Toe                 com.twofoxapps.tictactoe   Puzzle     0.0
# 162440  Tic Tac Toe                 com.tictactoe.board.glow    Board     0.0
# 163701  Tic Tac Toe  com.springmaru.androidGame.leoTicTacToe    Board     3.6
#
#         Rating Count    Installs  Minimum Installs  Maximum Installs  Free  \
# 3918             0.0         10+              10.0              30.0  True
# 13758            0.0         10+              10.0              31.0  True
# 25351           11.0      5,000+            5000.0            6379.0  True
# 28142            0.0        500+             500.0             922.0  True
# 30962            0.0         10+              10.0              38.0  True
# 42602         7894.0    500,000+          500000.0          854872.0  True
# 48854            0.0         10+              10.0              28.0  True
# 52301            8.0        100+             100.0             130.0  True
# 58474            0.0          5+               5.0               7.0  True
# 71416            0.0         10+              10.0              26.0  True
# 83551          109.0     50,000+           50000.0           53754.0  True
# 92824            NaN         10+              10.0              11.0  True
# 93663           15.0         50+              50.0              72.0  True
# 94848           11.0        100+             100.0             149.0  True
# 94997            0.0         10+              10.0              48.0  True
# 105963           0.0          1+               1.0               4.0  True
# 109212           0.0         50+              50.0              62.0  True
# 113737           0.0         50+              50.0              62.0  True
# 117146           0.0          1+               1.0               3.0  True
# 121083           0.0         10+              10.0              43.0  True
# 121529           0.0         10+              10.0              18.0  True
# 125780          15.0         10+              10.0              33.0  True
# 129993       23033.0  1,000,000+         1000000.0         2048367.0  True
# 139673          32.0      1,000+            1000.0            1913.0  True
# 150628           6.0        100+             100.0             243.0  True
# 153658           0.0         10+              10.0              32.0  True
# 157170           0.0         10+              10.0              39.0  True
# 157357          18.0        100+             100.0             159.0  True
# 157422           0.0          5+               5.0               8.0  True
# 161618           0.0        100+             100.0             229.0  True
# 162440           0.0          5+               5.0               8.0  True
# 163701          10.0      1,000+            1000.0            2066.0  True
#
#         Price Currency                Size     Minimum Android  \
# 3918      0.0      USD                3.4M          4.0 and up
# 13758     0.0      USD                 34M          4.3 and up
# 25351     0.0      USD                7.4M          7.0 and up
# 28142     0.0      USD                8.6M          4.1 and up
# 30962     0.0      USD                927k          4.0 and up
# 42602     0.0      USD                2.2M          4.0 and up
# 48854     0.0      USD                3.5M          4.2 and up
# 52301     0.0      USD                5.5M          2.2 and up
# 58474     0.0      USD  Varies with device          4.1 and up
# 71416     0.0      USD                1.4M          5.1 and up
# 83551     0.0      USD                6.1M        4.0.3 and up
# 92824     0.0      USD  Varies with device  Varies with device
# 93663     0.0      USD                2.5M          4.2 and up
# 94848     0.0      USD                9.6M          5.0 and up
# 94997     0.0      USD                4.3M          4.1 and up
# 105963    0.0      USD                3.1M          5.0 and up
# 109212    0.0      USD                6.6M          5.0 and up
# 113737    0.0      USD                 36M          5.0 and up
# 117146    0.0      USD                 17M          4.4 and up
# 121083    0.0      USD                1.9M          4.4 and up
# 121529    0.0      USD                1.5M          4.4 and up
# 125780    0.0      USD                1.5M          4.4 and up
# 129993    0.0      USD                8.8M          4.1 and up
# 139673    0.0      USD                 10M          6.0 and up
# 150628    0.0      USD              1,022k          2.2 and up
# 153658    0.0      USD                7.2M          4.1 and up
# 157170    0.0      USD                5.9M          5.0 and up
# 157357    0.0      USD                5.4M          4.1 and up
# 157422    0.0      USD                1.4M          4.1 and up
# 161618    0.0      USD                3.9M          5.1 and up
# 162440    0.0      USD                6.3M          4.1 and up
# 163701    0.0      USD                 32M          4.1 and up
#
#                                Developer Id  \
# 3918                      ATTE AKA FRANCOIS
# 13758                   Smart Digital Tools
# 25351               Sundeep Reddy Thirumuru
# 28142                       SteadFast Games
# 30962                          SnatchDreams
# 42602                     Suneetha Marthala
# 48854                           Nesim Razon
# 52301                                 Hawks
# 58474                         Kiran Neupane
# 71416                               Eastesh
# 83551                       Popoko VM Games
# 92824                         Barrica Games
# 93663                           Pritesh1995
# 94848                          Eros Dev Inc
# 94997                        Prathik Preman
# 105963                  Mak Bros Production
# 109212                     Agroup Technolab
# 113737                          Luv Barnwal
# 117146                          Lord Bailey
# 121083                        Walid Behloul
# 121529                        Abhinn Krishn
# 125780                     Harsh Singh@2206
# 129993                     The Angry Kraken
# 139673                 Progressio Technolab
# 150628                 Prolific Development
# 153658                            UldixApps
# 157170                           Kaal Group
# 157357                     Soumyadip Sarkar
# 157422              Smart Jaguar Developers
# 161618                                2Fox!
# 162440  Status Saver Download Videos/Images
# 163701                           SPRINGMARU
#
#                           Developer Website  \
# 3918      https://ne2ad32ee.app-ads-txt.com
# 13758                                   NaN
# 25351                                   NaN
# 28142                                   NaN
# 30962          https://www.snatchdreams.net
# 42602                                   NaN
# 48854           http://nrazon.blogspot.com/
# 52301                                   NaN
# 58474                                   NaN
# 71416                                   NaN
# 83551                   https://popoko.live
# 92824                                   NaN
# 93663                                   NaN
# 94848                   https://erosdev.com
# 94997                 http://www.prathik.in
# 105963                                  NaN
# 109212                                  NaN
# 113737                                  NaN
# 117146                                  NaN
# 121083                                  NaN
# 121529                                  NaN
# 125780                                  NaN
# 129993        http://www.theangrykraken.com
# 139673                                  NaN
# 150628               http://ProlificDev.com
# 153658                                  NaN
# 157170                                  NaN
# 157357            https://impapan.github.io
# 157422                                  NaN
# 161618      https://2fox.000webhostapp.com/
# 162440                                  NaN
# 163701  https://www.facebook.com/springmaru
#
#                           Developer Email      Released  Last Updated  \
# 3918          dev.atte.francois@gmail.com  May 18, 2018  May 18, 2018
# 105963       Everyone                                                NaN
# 109212       Everyone                                                NaN
# 113737       Everyone                http://www.luvbarnwal.in/Policy.php
# 117146       Everyone                                                NaN
# 121083       Everyone  https://sites.google.com/view/walid-behloul/ac...
# 121529       Everyone                                                NaN
# 125780       Everyone                                                NaN
# 129993       Everyone               http://www.theangrykraken.com/terms/
# 139673       Everyone  https://firebasestorage.googleapis.com/v0/b/pr...
# 150628       Everyone                                                NaN
# 153658       Everyone                                                NaN
# 157170       Everyone  https://tic-tac-toe-52.flycricket.io/privacy.html
# 157357       Everyone                                                NaN
# 157422       Everyone                                                NaN
# 161618       Everyone                                                NaN
# 162440       Everyone                                                NaN
# 163701       Everyone  https://www.facebook.com/notes/springmaru/spri...
#
#        Ad Supported In App Purchases Editors Choice         Scraped Time
# 3918           True            False          False  2021-06-15 20:23:22
# 13758          True            False          False  2021-06-15 20:32:58
# 25351          True            False          False  2021-06-15 20:44:27
# 28142          True            False          False  2021-06-15 20:47:17
# 30962          True            False          False  2021-06-15 20:50:12
# 42602          True            False          False  2021-06-15 21:01:52
# 48854          True            False          False  2021-06-15 21:08:01
# 52301          True            False          False  2021-06-15 21:11:26
# 58474         False            False          False  2021-06-15 21:17:42
# 71416         False            False          False  2021-06-15 21:30:16
# 83551          True             True          False  2021-06-15 21:42:04
# 92824         False            False          False  2021-06-15 21:51:26
# 93663          True            False          False  2021-06-15 21:52:14
# 94848          True             True          False  2021-06-15 21:53:25
# 94997         False            False          False  2021-06-15 21:53:34
# 105963         True            False          False  2021-06-15 22:04:04
# 109212         True            False          False  2021-06-15 22:07:12
# 113737         True            False          False  2021-06-15 22:11:42
# 117146         True            False          False  2021-06-15 22:14:57
# 121083         True            False          False  2021-06-15 22:18:37
# 121529        False            False          False  2021-06-15 22:19:03
# 125780        False            False          False  2021-06-15 22:23:13
# 129993         True            False          False  2021-06-15 22:27:16
# 139673         True             True          False  2021-06-15 22:36:31
# 150628        False            False          False  2021-06-15 22:47:55
# 153658         True            False          False  2021-06-15 22:51:02
# 157170         True            False          False  2021-06-15 22:54:30
# 157357        False            False          False  2021-06-15 22:54:42
# 157422        False            False          False  2021-06-15 22:54:46
# 161618         True            False          False  2021-06-15 22:59:05
# 162440         True            False          False  2021-06-15 23:00:07
# 163701         True            False          False  2021-06-15 23:02:10

# %%
df['App Id'].duplicated().any()
# Out:
# False

# %%
df['App Id'].value_counts()
# Out:
# com.ishakwe.gakondo                       1
# com.noliapp                               1
# com.leveil.leveil                         1
# com.nobexinc.wls_78980598.rc              1
# com.radioiri.wcrsco                       1
#                                          ..
# com.sms.free.donut.maker.dessert.games    1
# com.fes10.mobil                           1
# com.libazart                              1
# com.mario.kart.minecraftpe                1
# com.tripbuilder.ase365                    1
# Name: App Id, Length: 179129, dtype: int64

# %% [markdown]
#
# 1. we have the Apps with the same names but with the unique App IDs so the Apps are differed based on the App IDs

# %% [markdown]
# ## let's Explore the numerical columns

# %%
df['Installs'].unique()
# Out:
# array(['10+', '5,000+', '50+', '100+', '1,000+', '500+', '50,000+',
#        '10,000+', '1+', '500,000+', '100,000+', '5+', '10,000,000+',
#        '1,000,000+', '5,000,000+', '0+', '100,000,000+', '50,000,000+',
#        '1,000,000,000+', '500,000,000+', '5,000,000,000+'], dtype=object)

# %% [markdown]
# It is in the object type, we need to change it into the int type

# %%
df['Installs'] = df['Installs'].str.split('+').str[0]    # reomoves the + symbol
df['Installs'].replace(',','', regex=True, inplace=True) #replace the commas ',' in the install column
df['Installs'] = df['Installs'].astype(int)              # converting it to the int type

# %%
df['Installs'].unique()
# Out:
# array([        10,       5000,         50,        100,       1000,
#               500,      50000,      10000,          1,     500000,
#            100000,          5,   10000000,    1000000,    5000000,
#                 0,  100000000,   50000000, 1000000000,  500000000,
#        5000000000])

# %%
df['Size'].unique()
# Out:
# array(['10M', '2.9M', '3.7M', ..., '262M', '398M', '593k'], dtype=object)

# %% [markdown]
# The Size of data can be in GB, MB and KB let's convert the data into the size in MB

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)

# %%
df['Size'].unique()
# Out:
# array(['10', '2.9', '3.7', ..., '262', '398', '593k'], dtype=object)

# %%
df[df['Size']=="1,018k"]
# Out:
#                             App Name                            App Id  \
# 313     PHOENIX CONTACT VISU+ mobile  de.phoenixcontect.visuplusmobile
# 138324                  RandomNumber   com.alsrleowkd9073.randomnumber
#
#         Category  Rating  Rating Count  Installs  Minimum Installs  \
# 313     Business     3.0           7.0      1000            1000.0
# 138324     Tools     4.4          47.0     10000           10000.0
#
#         Maximum Installs  Free  Price Currency    Size Minimum Android  \
# 313               2596.0  True    0.0      USD  1,018k      4.1 and up
# 138324           24028.0  True    0.0      USD  1,018k    4.0.3 and up
#
#                          Developer Id             Developer Website  \
# 313     Phoenix Contact GmbH & Co. KG  http://www.phoenixcontact.de
# 138324                 Directory_Root                           NaN
#
#                      Developer Email      Released  Last Updated  \
# 313     phoenixcontactemag@gmail.com   Aug 5, 2014  Jun 25, 2020
# 138324           alsrl0304@gmail.com  Feb 25, 2016  Jun 03, 2015
#
#        Content Rating                                     Privacy Policy  \
# 313          Everyone  http://www.phoenixcontact.com/corporate_data_p...
# 138324       Everyone                                                NaN
#
#        Ad Supported In App Purchases Editors Choice         Scraped Time
# 313           False            False          False  2021-06-15 20:19:54
# 138324        False            False          False  2021-06-15 22:35:14

# %%
#df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)

# %% [markdown]
# here we get a missmatched value with the data
# we got the value 1,018 we can drop it or we can assume as it may be a '.' (dot) the would incorrectly added to the dataset. so let assume it as dot for now and repalce the ',' with the dot '.'

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace(',', '.') if ',' in str(x) else x)

# %%
df[df['Size']=="1,018k"]
# Out:
# Empty DataFrame
# Columns: [App Name, App Id, Category, Rating, Rating Count, Installs, Minimum Installs, Maximum Installs, Free, Price, Currency, Size, Minimum Android, Developer Id, Developer Website, Developer Email, Released, Last Updated, Content Rating, Privacy Policy, Ad Supported, In App Purchases, Editors Choice, Scraped Time]
# Index: []

# %% [markdown]
# conversion of kbs to mb

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)

# %%
#df['Size'] = df['Size'].apply(lambda x: float(x))

# %%
df['Size'].unique()
# Out:
# array(['10', '2.9', '3.7', ..., '262', '398', 0.593], dtype=object)

# %% [markdown]
# we get an another missmatch value in the data set which is 'Varies with device' it means the size of the App may vaies with the device---> but here I am assuming it as 0

# %%
df['Size'] = df['Size'].apply(lambda x: str(x).replace('Varies with device', '0') if 'Varies with device' in str(x) else x)

# %%
#df['Size'] = df['Size'].apply(lambda x: float(x))

# %% [markdown]
# conversion of data Gbs to Mb

# %%
df['Size'] = df['Size'].apply(lambda x: float(str(x).replace('G', '')) * 1000 if 'G' in str(x) else x)

# %%
df['Size'] = df['Size'].apply(lambda x: float(x))

# %%
df.dtypes['Size']
# Out:
# dtype('float64')

# %%
df['Free']
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 179157    True
# 179158    True
# 179159    True
# 179160    True
# 179161    True
# Name: Free, Length: 179129, dtype: object

# %%
df['Free'].unique()
# Out:
# array([True, False], dtype=object)

# %% [markdown]
# Creataing the column type for free and paid Apps by using the Free column, it's helpfull while dealing with the paid and Free Apps

# %%
df['Type'] = np.where(df['Free'] == True,'Free','Paid')
df.drop(['Free'],axis=1, inplace= True )

# %% [markdown]
# let's clean the Content Rating column

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Mature 17+', 'Everyone 10+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           156710
# Teen                15262
# Mature 17+           4560
# Everyone 10+         2576
# Unrated                13
# Adults only 18+         8
# Name: Content Rating, dtype: int64

# %% [markdown]
# ## Observation :
# 1. we have variouss Categories in the content Rating column :
#    * Everyone
#    * Teen
#    * Mature 17+
#    * Everyone 10+
#    * Unrated
#    * Adults only 18+
#
# Now, we makes this Categories to a simple 3 Categories for better understanding :
#    Everyone, Teen, Adults
#
#    * Mature 17+   ----> to Adults
#    * Everyone 10+ ----> to Teen
#    * Unrated      ----> to Everyone
#    * Adults only 18+ -> to Adults

# %%
df["Content Rating"]=df["Content Rating"].replace("Unrated","Everyone")
df["Content Rating"]=df["Content Rating"].replace("Everyone 10+","Teen")
df["Content Rating"]=df["Content Rating"].replace("Mature 17+","Adults")
df["Content Rating"]=df["Content Rating"].replace("Adults only 18+","Adults")

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179129 entries, 0 to 179161
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   App Name           179129 non-null  object
#  1   App Id             179129 non-null  object
#  2   Category           179129 non-null  object
#  3   Rating             177407 non-null  float64
#  4   Rating Count       177407 non-null  float64
#  5   Installs           179129 non-null  int64
#  6   Minimum Installs   179129 non-null  float64
#  7   Maximum Installs   179129 non-null  float64
#  8   Price              179129 non-null  float64
#  9   Currency           179129 non-null  object
#  10  Size               179129 non-null  float64
#  11  Minimum Android    178612 non-null  object
#  12  Developer Id       179129 non-null  object
#  13  Developer Website  120477 non-null  object
#  14  Developer Email    179129 non-null  object
#  15  Released           173742 non-null  object
#  16  Last Updated       179129 non-null  object
#  17  Content Rating     179129 non-null  object
#  18  Privacy Policy     146774 non-null  object
#  19  Ad Supported       179129 non-null  object
#  20  In App Purchases   179129 non-null  object
#  21  Editors Choice     179129 non-null  object
#  22  Scraped Time       179129 non-null  object
#  23  Type               179129 non-null  object
# dtypes: float64(6), int64(1), object(17)
# memory usage: 34.2+ MB

# %%
df['Rating'].unique()
# Out:
# array([0. , 4.4, 5. , 4.5, 2. , 4.7, 4.9, 3.9, 3.7, 4.2, 3.4, 3.8, 4.6,
#        4.1, 2.5, 2.3, 2.1, 2.7, 4.3, 3.1, 4.8, 3.3, 4. , 2.4, 3.2, 3.6,
#        2.6, nan, 1.5, 3.5, 2.9, 1.3, 2.8, 3. , 2.2, 1.8, 1.4, 1.2, 1.9,
#        1.7, 1.6, 1. , 1.1])

# %%
df['Rating Count'].unique()
# Out:
# array([0.00000e+00, 6.40000e+01, 5.00000e+00, ..., 3.59800e+03,
#        1.79500e+03, 1.76584e+05])

# %% [markdown]
# let's change the Rating Count to certain ranges for the better understanding the data

# %%
df['Rating Count'].max()
# Out:
# 37479011.0

# %%
# df['Rating Type']

# %%
df['Rating Type'] = 'NoRatingProvided'
df['Rating Type']
# Out:
# 0         NoRatingProvided
# 1         NoRatingProvided
# 2         NoRatingProvided
# 3         NoRatingProvided
# 4         NoRatingProvided
#                 ...
# 179157    NoRatingProvided
# 179158    NoRatingProvided
# 179159    NoRatingProvided
# 179160    NoRatingProvided
# 179161    NoRatingProvided
# Name: Rating Type, Length: 179129, dtype: object

# %%
df.loc[(df['Rating Count'] > 0) & (df['Rating Count'] <= 10000.0),'Rating Type'] = 'Less than 10K'
df.loc[(df['Rating Count'] > 10000) & (df['Rating Count'] <= 500000.0),'Rating Type'] = 'Between 10K and 500K'
df.loc[(df['Rating Count'] > 500000) & (df['Rating Count'] <= 138557570.0),'Rating Type'] = 'More than 500K'
df['Rating Type'].value_counts()
# Out:
# Less than 10K           92353
# NoRatingProvided        83932
# Between 10K and 500K     2715
# More than 500K            129
# Name: Rating Type, dtype: int64

# %%
df['Rating Type']
# Out:
# 0             NoRatingProvided
# 1                Less than 10K
# 2             NoRatingProvided
# 3                Less than 10K
# 4             NoRatingProvided
#                   ...
# 179157        NoRatingProvided
# 179158        NoRatingProvided
# 179159           Less than 10K
# 179160    Between 10K and 500K
# 179161        NoRatingProvided
# Name: Rating Type, Length: 179129, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179129 entries, 0 to 179161
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   App Name           179129 non-null  object
#  1   App Id             179129 non-null  object
#  2   Category           179129 non-null  object
#  3   Rating             177407 non-null  float64
#  4   Rating Count       177407 non-null  float64
#  5   Installs           179129 non-null  int64
#  6   Minimum Installs   179129 non-null  float64
#  7   Maximum Installs   179129 non-null  float64
#  8   Price              179129 non-null  float64
#  9   Currency           179129 non-null  object
#  10  Size               179129 non-null  float64
#  11  Minimum Android    178612 non-null  object
#  12  Developer Id       179129 non-null  object
#  13  Developer Website  120477 non-null  object
#  14  Developer Email    179129 non-null  object
#  15  Released           173742 non-null  object
#  16  Last Updated       179129 non-null  object
#  17  Content Rating     179129 non-null  object
#  18  Privacy Policy     146774 non-null  object
#  19  Ad Supported       179129 non-null  object
#  20  In App Purchases   179129 non-null  object
#  21  Editors Choice     179129 non-null  object
#  22  Scraped Time       179129 non-null  object
#  23  Type               179129 non-null  object
#  24  Rating Type        179129 non-null  object
# dtypes: float64(6), int64(1), object(18)
# memory usage: 35.5+ MB

# %% [markdown]
# # Question and Aswers :
#
#
# *  What are the top 10 Categories that are installed from the Google Play Store ?
# *  Which are the Categories that are getting installed the most in top 10 Categories?
# *  What is the higest rated Category ?
#
# *  Which Category has the highest Paid and Free apps ?
# *  How does the size of the Application impacts the Installation ?
#
# *  What are the Top 5 Paid Apps based With highest ratings and installs ?
# *  What are the Top 5 Free Apps based With highest      ratings and installs ?

# %% [markdown]
# ## Q - What are the top 10 Categories that are installed from the Google Play Store ?

# %%
df['Category'].unique()
# Out:
# array(['Adventure', 'Tools', 'Productivity', 'Communication', 'Social',
#        'Libraries & Demo', 'Lifestyle', 'Personalization', 'Racing',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink',
#        'Books & Reference', 'Medical', 'Puzzle', 'Entertainment',
#        'Arcade', 'Auto & Vehicles', 'Photography', 'Health & Fitness',
#        'Education', 'Shopping', 'Board', 'Music & Audio', 'Sports',
#        'Beauty', 'Business', 'Educational', 'Finance', 'News & Magazines',
#        'Casual', 'Art & Design', 'House & Home', 'Card', 'Events',
#        'Trivia', 'Weather', 'Strategy', 'Word', 'Video Players & Editors',
#        'Action', 'Simulation', 'Music', 'Dating', 'Role Playing',
#        'Casino', 'Comics', 'Parenting'], dtype=object)

# %%
df.Category.value_counts()
# Out:
# Education                  18484
# Music & Audio              12266
# Tools                      11252
# Business                   11130
# Entertainment              10541
# Lifestyle                   9219
# Books & Reference           8991
# Personalization             6993
# Health & Fitness            6464
# Productivity                6217
# Shopping                    5868
# Food & Drink                5694
# Travel & Local              5341
# Finance                     5052
# Arcade                      4137
# Puzzle                      3925
# Casual                      3805
# Communication               3680
# Sports                      3645
# Social                      3610
# News & Magazines            3323
# Photography                 2815
# Medical                     2465
# Action                      2117
# Maps & Navigation           2037
# Simulation                  1840
# Adventure                   1810
# Educational                 1550
# Art & Design                1408
# Auto & Vehicles             1355
# House & Home                1107
# Video Players & Editors     1068
# Events                      1008
# Trivia                       893
# Beauty                       890
# Racing                       861
# Board                        834
# Role Playing                 780
# Word                         650
# Strategy                     647
# Card                         607
# Weather                      564
# Dating                       488
# Libraries & Demo             437
# Casino                       396
# Music                        343
# Parenting                    303
# Comics                       219
# Name: Category, dtype: int64

# %%
top_Category = df.Category.value_counts().reset_index().rename(columns={'Category':'Count','index':'Category'})

# %%
top_Category

# %%
Category_installs = df.groupby(['Category'])[['Installs']].sum()

# %%
Category_installs
# Out:
#                            Installs
# Category
# Action                   2473582234
# Adventure                 382692400
# Arcade                    771101566
# Art & Design               63344358
# Auto & Vehicles            34609986
# Beauty                     26564597
# Board                     271965019
# Books & Reference         356959464
# Business                  129689023
# Card                      122765970
# Casino                     96691072
# Casual                   1142464149
# Comics                      8898835
# Communication             489403606
# Dating                     29964827
# Education                 633307385
# Educational               282897363
# Entertainment            1958667048
# Events                      3600726
# Finance                   358768899
# Food & Drink               79324724
# Health & Fitness          289654697
# House & Home               26208205
# Libraries & Demo           29540168
# Lifestyle                 908930806
# Maps & Navigation         176955540
# Medical                    68675575
# Music                     118532701
# Music & Audio             747996124
# News & Magazines          258084053
# Parenting                  14947731
# Personalization           633582172
# Photography              1872458262
# Productivity             3385499239
# Puzzle                    913468109
# Racing                    739855308
# Role Playing              335061419
# Shopping                  471552146
# Simulation               1081379241
# Social                   1214555481
# Sports                    653299659
# Strategy                  275135613
# Tools                    2334077354
# Travel & Local            257404302
# Trivia                     60568509
# Video Players & Editors  5619534640
# Weather                   201911512
# Word                      161971568

# %%
top_Category_installs = pd.merge(top_Category, Category_installs, on='Category')
top_Category_installs.head(5)
# Out:
#         Category  Count    Installs
# 0      Education  18484   633307385
# 1  Music & Audio  12266   747996124
# 2          Tools  11252  2334077354
# 3       Business  11130   129689023
# 4  Entertainment  10541  1958667048

# %%
top_10_Categories_installs = top_Category_installs.head(10).sort_values(by = ['Installs'],ascending = False)

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Top 10 Installed Categories")
sns.barplot(x = top_10_Categories_installs.Category,y= top_10_Categories_installs.Installs)
# Out:
# <Axes: title={'center': 'Top 10 Installed Categories'}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# ## Ans - Tools, Productivity,Education, Music & Audio, Personalization, Lifestyle, Education, Business, Books & Reference, Health & Fitness

# %% [markdown]
# ## Q -  What are the 10 Categories in playstore as per the count?

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Top 10 Categories")
sns.barplot(x = top_10_Categories_installs.Category, y = top_10_Categories_installs.Count)
# Out:
# <Axes: title={'center': 'Top 10 Categories'}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# ##Ans - Education, Music & Audio, Tools, Business, Entertainment, Lifestyle, Books & Reference, Personalization, Health & Fitness, Productivity.

# %% [markdown]
# ## Observation :
# As we can see from the above two plots: Maxinum number of apps present in google play store comes under Education Tools, Business and Entertainment etc., Categories but as per the installation scenario it is different. Maximum installed apps comes under Tools, Productivity,Entertainment, Music & Audio etc.,

# %% [markdown]
# ## visualize Total Categories and the count of Apps in each category

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Total Categories and count of Applications in each category ")
sns.barplot(x = top_Category_installs.Category, y = top_Category_installs.Count)
# Out:
# <Axes: title={'center': 'Total Categories and count of Applications in each category '}, xlabel='Category', ylabel='Count'>

# %% [markdown]
# ## Visualize Total Categories and installed Applications in each category

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Number of applications")
plt.title("Total Categories and Installation of Applications in each category ")
sns.barplot(x = top_Category_installs.Category,y = top_Category_installs.Installs)
# Out:
# <Axes: title={'center': 'Total Categories and Installation of Applications in each category '}, xlabel='Category', ylabel='Installs'>

# %% [markdown]
# Rating distribution

# %%
plt.figure(figsize=(14,7))
g = sns.kdeplot(df.Rating, color="Blue", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
# Out:
# <ipython-input-420-a21c6a2a3d2d>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   g = sns.kdeplot(df.Rating, color="Blue", shade = True)
# Text(0.5, 1.0, 'Distribution of Rating')

# %% [markdown]
# ## Observation :
# From the above plot we can see that most people does not give a rating,But one more thing that comes out from this graph as well is that people tend to give 4+ rating the most.

# %% [markdown]
# ##Q - What is the highest rated Category?

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=90)
plt.xlabel("Highest Rated Category")
plt.ylabel("Number of applications")
plt.title("All Categories Rating ")
sns.barplot(x = df.Category,y = df.Rating)
# Out:
# <Axes: title={'center': 'All Categories Rating '}, xlabel='Category', ylabel='Rating'>

# %% [markdown]
# ## Ans - From the above plot we can see that Role Playing is the highest Rated category

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
df.head(50)
# Out:
#                                              App Name  \
# 0                                             Gakondo
# 1                                 Ampere Battery Info
# 2                                              Vibook
# 3   Smart City Trichy Public Service Vehicles 17UC...
# 4                                             GROW.me
# 5                                              IMOCCI
# 6                    unlimited 4G data prank free app
# 7                               The Everyday Calendar
# 8                                           WhatsOpen
# 9                    Neon 3d Iron Tech Keyboard Theme
# 10                                    Dodge The Cars!
# 11                                            Parents
# 12                     桃園機場捷運時刻表 - 捷運轉乘路線快速查詢(支援台北捷運)
# 13                                       be.MOBILISED
# 14                                  Caliway Conductor
# 15                              Readymade Grocery App
# 16                               OTENTIK Discovery FR
# 17                            All in one shopping app
# 18                                     REDMOND  Robot
# 19                     Contemporary Love Wallpaper HD
# 20                                    Nepali Congress
# 21                                  Bhavan's BHEL VIM
# 22                            Block Fill: Puzzle Game
# 23                              Coloring Book Barbaie
# 24                            Random Number Generator
# 25                                        Sticky Ball
# 26                                       CUBIC RUNNER
# 27                Dj Car Sound And Sound Effects 2019
# 28                                         Schoolbus*
# 29                                  Cambodian.Express
# 30                                       Barnets Hair
# 31                                            GaiaZOO
# 32       Photo Brightness Editor - Image Brighten App
# 33                                       Creepy Story
# 34                              Vancouver Bus Tracker
# 35                                 Serbia Audio Guide
# 36                                    Head Lice guide
# 37                  Calculus Tutorial 1: Introduction
# 38                             Business Class Fitness
# 39     Sudan Flag Wallpaper: Flags, Country HD Images
# 40                                          BuradaOto
# 41                                       MoveNow User
# 42                           Niagara Falls Wallpapers
# 43                                    Extrude Balance
# 44                                    1-Click Hotspot
# 45                            Psychrometry Calculator
# 46                                    Bounce & Bubble
# 47                                       Radio Louvor
# 48                        Peribahasa Bahasa Indonesia
# 49                          Bowling Paradise Pro FREE
#
#                                                App Id           Category  \
# 0                                 com.ishakwe.gakondo          Adventure
# 1                          com.webserveis.batteryinfo              Tools
# 2                                com.doantiepvien.crm       Productivity
# 3                             cst.stJoseph.ug17ucs548      Communication
# 4                                com.horodyski.grower              Tools
# 5                                          com.imocci             Social
# 6       getfreedata.superfatiza.unlimitedjiodataprank   Libraries & Demo
# 7                              com.mozaix.simoneboard          Lifestyle
# 8                                   com.whatsopen.app      Communication
# 9               com.ikeyboard.theme.neon_3d.iron.tech    Personalization
# 10               com.MrScratchEnterprises.CarDogeGame             Racing
# 11                       com.eqra.android.BSTS.parent  Maps & Navigation
# 12                            com.jieapp.taoyuanmetro     Travel & Local
# 13                            com.hastobe.bemobilised  Maps & Navigation
# 14                        com.caliwayconductor.driver     Travel & Local
# 15       com.ionicfirebaseapp.readymadegroceryuserapp       Food & Drink
# 16                   com.camineo.otentikdiscoveryDLFR     Travel & Local
# 17             com.tkapplications.allinoneshoppingapp              Tools
# 18                                   com.grit.redmond          Lifestyle
# 19                           com.felingdev.lowalpaper  Books & Reference
# 20                              np.com.NepaliCongress             Social
# 21                                    com.bhavans.vim            Medical
# 22  com.mailbeegames.casual.brain.line.block.puzzl...             Puzzle
# 23                                com.bisgumah.barbie      Entertainment
# 24                              com.gary.randomnumber              Tools
# 25                 com.mitochondriastudios.stickyball             Arcade
# 26                         jp.ga_software.cubicrunner             Arcade
# 27                      com.melonappsvpn.dj_carsounds      Entertainment
# 28                            com.forumloft.schoolbus  Maps & Navigation
# 29                                 com.cambodia.ceapp    Auto & Vehicles
# 30                            com.phorest.barnetshair          Lifestyle
# 31                            nl.haveaniceday.gaiazoo     Travel & Local
# 32                      image.photo.brightness.editor        Photography
# 33                               com.creepypasta.club      Entertainment
# 34                         beyond.translinkbustracker  Maps & Navigation
# 35                                   apetra.tourguide     Travel & Local
# 36                    com.andromo.dev667101.app672597   Health & Fitness
# 37                         com.RaySemiSoft.CalculusT1          Education
# 38                com.bhappdevelopment.samuelvankuren   Health & Fitness
# 39                     com.techzit.sudanflagwallpaper    Personalization
# 40                             com.rzmobile.buradaoto           Shopping
# 41                                com.movenowcustomer     Travel & Local
# 42            com.niagara.wallpapers.backgrounds_0001    Personalization
# 43                  com.creatorsbureau.extrudebalance             Arcade
# 44                  com.one.click.wifi.tethering.free              Tools
# 45                        com.s3software.psychrometry              Tools
# 46                              com.game.bouncebubble              Board
# 47                               hoostcomv2.francisco      Music & Audio
# 48                    com.andromo.dev298605.app412818  Books & Reference
# 49                 com.innolab.BowlingParadiseProFREE             Sports
#
#     Rating  Rating Count  Installs  Minimum Installs  Maximum Installs  Price  \
# 0      0.0           0.0        10              10.0              15.0    0.0
# 1      4.4          64.0      5000            5000.0            7662.0    0.0
# 2      0.0           0.0        50              50.0              58.0    0.0
# 3      5.0           5.0        10              10.0              19.0    0.0
# 4      0.0           0.0       100             100.0             478.0    0.0
# 5      0.0           0.0        50              50.0              89.0    0.0
# 6      4.5          12.0      1000            1000.0            2567.0    0.0
# 7      2.0          39.0       500             500.0             702.0    0.0
# 8      0.0           0.0        10              10.0              18.0    0.0
# 9      4.7         820.0     50000           50000.0           62433.0    0.0
# 10     4.9          55.0       100             100.0             329.0    0.0
# 11     0.0           0.0       100             100.0             330.0    0.0
# 12     3.9         118.0     10000           10000.0           37763.0    0.0
# 13     0.0           0.0       100             100.0             274.0    0.0
# 14     3.7        1572.0     10000           10000.0           42856.0    0.0
# 15     4.2          16.0      1000            1000.0            4313.0    0.0
# 16     3.4           5.0       500             500.0             949.0    0.0
# 17     5.0           6.0        50              50.0              62.0    0.0
# 22      USD  16.0      5.0 and up                        MailBee Games
# 23      USD  20.0      5.0 and up                             bisgumah
# 24      USD   2.4      5.0 and up                           GaryG Apps
# 25      USD  25.0      4.1 and up                 Mitochondria Studios
# 26      USD  16.0      4.0 and up                          GA software
# 27      USD  21.0    4.0.3 and up                        TenSept Tools
# 28      USD  11.0      2.1 and up                            Forumloft
# 29      USD   6.2      4.1 and up                             CCIT.TMS
# 30      USD  36.0      5.0 and up                              Phorest
# 31      USD   7.6      4.4 and up                          Myler Media
# 32      XXX   6.2      4.4 and up                           Anuoluwapo
# 33      USD   6.1      4.1 and up               AL Hidayah Corporation
# 34      USD   2.6      4.0 and up                           Beyond 2.0
# 35      USD  11.0      4.1 and up                           NTO Serbia
# 36      USD   3.7      4.1 and up               Free Apps For Everyone
# 37      USD  15.0      4.1 and up                          RaySemiSoft
# 38      USD  10.0      7.0 and up               BH App Development Ltd
# 39      USD   8.9      5.0 and up                               TZLabs
# 40      USD   3.9    4.0.3 and up                            Buradaoto
# 41      USD  30.0      4.1 and up                           MoveNowApp
# 42      USD  21.0      4.1 and up                          Legend APPS
# 43      USD  26.0      5.0 and up                      Creators Bureau
# 44      USD   4.9      4.1 and up                       Limonland Apps
# 45      USD   4.3    4.0.3 and up                             MEPPEDIA
# 46      USD   4.8      2.2 and up                  Kossta Tech Systems
# 47      USD   4.6      5.0 and up                                Hoost
# 48      USD   2.8      4.1 and up                        Irwana Studio
# 49      USD  38.0      2.1 and up                              InnoLab
#
#                                     Developer Website  \
# 0                         https://beniyizibyose.tk/#/
# 1                     https://webserveis.netlify.app/
# 2                                                 NaN
# 3                    http://www.climatesmarttech.com/
# 4                         http://www.horodyski.com.pl
# 5                               http://www.imocci.com
# 6                                                 NaN
# 7                                                 NaN
# 8                            http://yilvermolinah.com
# 9                 https://trendyteme888-31139.web.app
# 10                                                NaN
# 11                          http://www.hafizquran.com
# 12                     https://jie-app.herokuapp.com/
# 13                           http://www.has-to-be.com
# 14                   https://www.facebook.com/waycali
# 15  https://www.ionicfirebaseapp.com/products/read...
# 16                     http://www.hotels-attitude.com
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                         https://nepalicongress.org
# 21                     http://www.bhavansbhelhyd.com/
# 22                            http://mailbeegames.net
# 23                https://appsabsadstxt.blogspot.com/
# 24                                                NaN
# 25                                                NaN
# 26                    http://ga-software.blogspot.jp/
# 27                                                NaN
# 28                               http://forumloft.com
# 29                                                NaN
# 30                                                NaN
# 31                              http://www.gaiazoo.nl
# 32                                 https://spobam.com
# 33                                                NaN
# 34                             http://www.Beyond20.ca
# 35                              http://www.tos.org.rs
# 36      https://w17cdeb7b.app-ads-txt.com/app-ads.txt
# 37                                                NaN
# 38                                                NaN
# 39                             https://toolsfairy.com
# 40                         https://www.buradaoto.com/
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                  https://uc294d7b9.app-ads-txt.com
# 45                                http://Meppedia.com
# 46                          http://www.kosstatech.com
# 47                                                NaN
# 48                           https://irwanastudio.com
# 49                          http://www.innolab-au.com
#
#                        Developer Email      Released  Last Updated  \
# 0               jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2
# 6      Less than 10K      7.801631
# 7      Less than 10K      4.050457
# 8   NoRatingProvided      7.538785
# 9      Less than 10K      4.520497
# 10     Less than 10K      7.424303
# 11  NoRatingProvided      0.301030
# 12     Less than 10K      8.434280
# 13  NoRatingProvided      5.163865
# 14     Less than 10K      8.551880
# 15     Less than 10K      5.782821
# 16     Less than 10K      8.112092
# 17     Less than 10K      5.383869
# 18     Less than 10K      8.088967
# 19  NoRatingProvided      4.495003
# 20  NoRatingProvided      7.985274
# 21  NoRatingProvided      4.397940
# 22     Less than 10K      9.057660
# 23     Less than 10K      5.681508
# 24     Less than 10K      6.949333
# 25     Less than 10K      1.000000
# 26  NoRatingProvided      8.688749
# 27  NoRatingProvided      6.014352
# 28     Less than 10K      7.476610
# 29     Less than 10K      2.000000
# 30  NoRatingProvided      8.801150
# 31     Less than 10K      5.830346
# 32     Less than 10K      8.451098
# 33  NoRatingProvided      5.538895
# 34     Less than 10K      9.291936
# 35     Less than 10K      5.049950
# 36     Less than 10K      6.556383
# 37  NoRatingProvided      1.740363
# 38  NoRatingProvided      8.554581
# 39  NoRatingProvided      5.286223
# 40     Less than 10K      7.898745
# 41  NoRatingProvided      5.083054
# 42     Less than 10K      8.461357
# 43     Less than 10K      5.542891
# 44     Less than 10K      7.418417
# 45     Less than 10K      3.083144
# 46  NoRatingProvided      7.469632
# 47  NoRatingProvided      4.725144
# 48     Less than 10K      8.958502
# 49     Less than 10K      4.784867

# %%
df[['Maximum Installs']]
# Out:
#         Maximum Installs
# 0                   15.0
# 1                 7662.0
# 2                   58.0
# 3                   19.0
# 4                  478.0
# ...                  ...
# 179157              19.0
# 179158             434.0
# 179159             213.0
# 179160        46615448.0
# 179161             155.0
#
# [179129 rows x 1 columns]

# %%
plt.figure(figsize=(8,8))
plt.title("Content Rating and Maximum installations ")
sns.scatterplot(x='Maximum Installs',y='Rating Count',data=df,hue='Content Rating')
# Out:
# <Axes: title={'center': 'Content Rating and Maximum installations '}, xlabel='Maximum Installs', ylabel='Rating Count'>

# %% [markdown]
# ## Observation :
# This scatterplot shows us that:
#  If we exclude everyone from the plot and when focus on Teen and Adults we can see that teens have much engagement in terms of download and rating count.

# %% [markdown]
# ##Q - Which Category has the highest Paid and Free apps ?

# %%
app_count = df.groupby(['Category','Type'])[['App Name']].count().reset_index().rename(columns={'App Name':'Count','index':'App Name'})
df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()
# Out:
# <ipython-input-425-c3390bac1d36>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_app_count = app_count.pivot('Category', 'Type', 'Count').fillna(0).reset_index()

# %%
df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9)) # try df_app_count.plot(kind='bar', stacked=True, figsize=(18,9))
plt.xlabel("Category", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Free and Paid Apps in Category")
# Out:
# Text(0.5, 1.0, 'Free and Paid Apps in Category')

# %% [markdown]
# ## Ans - Education Category is the highest in paid apps list

# %% [markdown]
# ## Observation :
# It looks like certain app categories have more free apps available for download than others. In our dataset, the majority of apps in Business,Education, Music & Audio, Tools as well as Social categories were free to install. At the same time Books & References, Education, Tools and Personalization categories had the biggest number of paid apps available for Installation.

# %% [markdown]
# ##visualize the Installation Types in each category

# %%
df['Installs'].min(),df['Installs'].max()
# Out:
# (0, 5000000000)

# %% [markdown]
# There is a high variance in the number of installs, we need to reduce it so we can use a log value for this column, otherwise it would be unable to see the data when we visualize

# %%
categoty_type_installs = df.groupby(['Category','Type'])[['Installs']].sum().reset_index()
categoty_type_installs['log_Installs'] = np.log10(categoty_type_installs['Installs'])

# %%
plt.figure(figsize=(18,9))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel("Category")
plt.ylabel("Installs")
plt.title("Number of installed Apps type wise according to Category")
sns.barplot(x = 'Category', y = 'log_Installs', hue='Type', data=categoty_type_installs)
# Out:
# <Axes: title={'center': 'Number of installed Apps type wise according to Category'}, xlabel='Category', ylabel='log_Installs'>

# %% [markdown]
# ##Q - How does the size of the Application impacts the Installation ?

# %%
df['log_Installs'] = np.log10(categoty_type_installs['Installs'])

# %%
plt.figure(figsize=(14,7))
plt.xlabel("Size")
plt.ylabel("Installs")
plt.title("Impact of Application Size in Installation")
sns.scatterplot(x = 'Size',y = 'Installs', hue='Type', data=df)
# Out:
# <Axes: title={'center': 'Impact of Application Size in Installation'}, xlabel='Size', ylabel='Installs'>

# %% [markdown]
# ##Ans - from the above plot we can see that size impacts the number of installations. Applications with large size are less installed by the user.

# %% [markdown]
# ## Let's see some correlations

# %%
df.corr()
# Out:
# <ipython-input-432-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Rating  Rating Count  Installs  Minimum Installs  \
# Rating            1.000000      0.018591  0.012822          0.012822
# Rating Count      0.018591      1.000000  0.295747          0.295747
# Installs          0.012822      0.295747  1.000000          1.000000
# Minimum Installs  0.012822      0.295747  1.000000          1.000000
# Maximum Installs  0.015923      0.340163  0.985822          0.985822
# Price            -0.003828     -0.000808 -0.000681         -0.000681
# Size              0.046341      0.020500  0.007631          0.007631
# log_Installs     -0.027114      0.074954  0.076510          0.076510
#
#                   Maximum Installs     Price      Size  log_Installs
# Rating                    0.015923 -0.003828  0.046341     -0.027114
# Rating Count              0.340163 -0.000808  0.020500      0.074954
# Installs                  0.985822 -0.000681  0.007631      0.076510
# Minimum Installs          0.985822 -0.000681  0.007631      0.076510
# Maximum Installs          1.000000 -0.000842  0.009843      0.078086
# Price                    -0.000842  1.000000  0.007123           NaN
# Size                      0.009843  0.007123  1.000000      0.039590
# log_Installs              0.078086       NaN  0.039590      1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),cbar= True, cmap='coolwarm')
# Out:
# <ipython-input-433-20339db5f703>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar= True, cmap='coolwarm')
# <Axes: >

# %% [markdown]
# ##Observation :
#  Factors like AdSupport and InappPurchases are correlated to app rating. So we can say that if the app provides customer support and have subscription plans we can engage more customers. We can also see from the same graph that the editor's choice plays a important role as well. With high editor choice we can see high ratings count and high installs.

# %% [markdown]
# ##Q - What are the Top 5 Paid Apps based With highest ratings and installs ?

# %%
df['Installs'].max()
# Out:
# 5000000000

# %%
paid_apps = df[(df.Type=='Paid') & (df.Installs >= 5000000)]
paid_apps = paid_apps.groupby('App Name')['Rating'].max().sort_values(ascending = False)

# %%
plt.figure(figsize=(8,4))
plt.xlabel("Rating")
sns.set_theme(style="whitegrid")
plt.title("Top 5 Paid Rated Apps")
sns.lineplot(x=paid_apps.values,y=paid_apps.index,color='Blue')
# Out:
# <Axes: title={'center': 'Top 5 Paid Rated Apps'}, xlabel='Rating', ylabel='App Name'>

# %% [markdown]
# ## Ans - Minecraft, Hitman Sniper, True Skate, Stickman Legends-Shadow Fight Premium Offline Game, Poweramp Full Version Unlocker, League of Stickman 2020- Ninja Arena PVP(Dreamsky)

# %% [markdown]
# ##Q - What are the Top 5 Free Apps based With highest ratings and installs ?

# %%
free_apps = df[(df.Type=='Free') & (df.Installs >= 5000000)]
free_apps = free_apps.groupby('App Name')['Rating'].max().sort_values(ascending = False)
free_apps = free_apps.head(5)

# %%
plt.figure(figsize=(8,4))
plt.xlabel("Rating")
sns.set_theme(style="whitegrid")
plt.title("Top 5 Free Rated Apps")
sns.lineplot(x = free_apps.values, y = free_apps.index,color = 'Blue')
# Out:
# <Axes: title={'center': 'Top 5 Free Rated Apps'}, xlabel='Rating', ylabel='App Name'>

# %% [markdown]
# ## Ans - Photo Frame, Video maker with photo & music, Kuku FM - Love Stories,Audio Books & Podcasts, Plank Workout at Home.

# %% [markdown]
# ## Visualize the categories that have the Top 10  Max Installations

# %%
plt.figure(figsize=(8,6))
data = df.groupby('Category')['Maximum Installs'].max().sort_values(ascending = True)
data = data.head(10)
labels = data.keys()
plt.pie(data, labels= labels,autopct='%.0f%%')
plt.title("Top 10 Max installations Category wise", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Top 10 Max installations Category wise')

# %% [markdown]
# ## Visualize the Top 10 installation Categories that Adults have installed the most

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
plt.figure(figsize=(8,6))
Adult = df[(df['Content Rating']=='Adults')]
Adult = Adult.groupby(['Category'])['Maximum Installs'].max().sort_values(ascending=False)
Adult = Adult.head(10)
labels = Adult.keys()
plt.pie(x = Adult, autopct="%.1f%%", labels=labels)
plt.title("Adults Installing apps in terms of category", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Adults Installing apps in terms of category')

# %% [markdown]
# ## Observation :
# Most of the Adults showing intrest in downloading the Social, Action and Communication Category

# %% [markdown]
# ## visualize Teens Installing the apps in terms of Category

# %%
plt.figure(figsize=(8,6))
Teen = df[(df['Content Rating']=='Teen')]
Teen = Teen.groupby(['Category'])['Maximum Installs'].max().sort_values(ascending=False)
Teen = Teen.head(10)
labels = Teen.keys()
plt.pie(x = Teen, autopct="%.1f%%", labels=labels)
plt.title("Teen Installing apps in terms of category", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Teen Installing apps in terms of category')

# %% [markdown]
# # **Summary and Conclusion** :
# * People are more intrested to install the gaming Apps, the top Rating is given to the gaming apps.
# * InAppPurchases are correlated to App rating. So we can say that if the app provides customer support and have subscription plans it will helps to engage customers.
# * most people does not gave rating, But the people who are given rating are tend to give 4+ rating the most.
# * Most of the Audlts installed the Social and communication Apps.
# * Most of the installations are done by the teens and the most are Video Players and Editors. Video Players and Editors has more demand.
# * Size of the Application varies the installations.
# * People are mostly dwonladed the free apps the installation of the free apps is high and the availabilty of the free apps also is very high.
